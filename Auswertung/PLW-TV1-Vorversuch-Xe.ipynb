# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
# %matplotlib inline
#%matplotlib qt5
#%matplotlib notebook

# %%
I_1_0, lambda_0, sigma_0 = np.loadtxt('TV1-Vorversuch-Xe.txt', skiprows=10, unpack=True)
plt.plot(I_1_0, lambda_0)
#plt.plot(I_1_0, sigma_0)
plt.xlabel('lambda')
plt.ylabel('I_1')
plt.title('Spektrum Xe')
# Out:
# UsageError: Line magic function `%plt.plot(I_1_0,` not found.

# %%
zeit_1 = zeit_0[1020:]

# %%
ausgang_1=ausgang_0[1020:]
plt.plot(zeit_1, ausgang_1)

# %%
zeit = zeit_1 / 125 * 50e-6
ausgang = ausgang_1 / 32*1
plt.plot(zeit, ausgang)

# %%
plt.xlabel('Zeit / s')
# Out:
# Text(0.5, 0, 'Zeit / s')

# %%
plt.ylabel('Spannung / v')
# Out:
# Text(0, 0.5, 'Spannung / v')

# %%
plt.plot(zeit, ausgang)

# %%
plt.plot(zeit, ausgang)
plt.xlabel('Zeit / s')
plt.ylabel('Spannung / v')
# Out:
# Text(0, 0.5, 'Spannung / v')

# %%
def fit_function_1(t, Ue, tau, offset):
    return Ue * (1 - np.exp(-t/tau)) + offset

popt_1, pcov = curve_fit(fit_function_1, zeit, ausgang, p0 =[10, 0.0005, -5])
print(popt_1)
# Out:
# [ 1.11574766e+01  4.81304859e-04 -4.85466334e+00]

# %%
plt.figure(figsize = (10, 6))
plt.plot(zeit, ausgang)
plt.plot(zeit, fit_function_1(zeit, *popt_1))
plt.xlabel('Zeit / s')
plt.ylabel('Spannung / v')
# Out:
# Text(0, 0.5, 'Spannung / v')

# %%
plt.figure(figsize=(10,6))
plt.plot(zeit[::100], ausgang[::100], linestyle = "None", marker = ".", label = "Messung")
plt.plot(zeit, fit_function_1(zeit, *popt_1), label="Fit")
plt.xlabel('Zeit / s')
plt.ylabel('Spannung / v')
plt.legend()
plt.title("Spannung am Kondensator")
# Out:
# Text(0.5, 1.0, 'Spannung am Kondensator')
